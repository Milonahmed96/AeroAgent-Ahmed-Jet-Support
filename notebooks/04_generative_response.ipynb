# %% [markdown]
# # Phase 4: Generative Response
# Testing the final AI drafting of the professional customer email.

# %%
import sys
sys.path.append('..')
from google.colab import userdata
from src import extractor, generator
api_key = userdata.get('GEMINI_API_KEY')
client = extractor.get_ai_client(api_key)

# Mock routing decision
decision = {'status': 'success', 'part_number': 'VLV-1010-MOD', 'condition': 'OH', 'match_type': 'Alternate Match'}
email = generator.draft_quote_email(decision, client)
print(email)
