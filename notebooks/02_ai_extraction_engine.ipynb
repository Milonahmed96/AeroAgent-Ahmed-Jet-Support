# %% [markdown]
# # Phase 2: AI Extraction Engine
# Prototyping the conversion of unstructured AOG emails into structured JSON objects.

# %%
import sys
sys.path.append('..')
from google.colab import userdata
from src import extractor
api_key = userdata.get('GEMINI_API_KEY')
client = extractor.get_ai_client(api_key)

email = 'URGENT: Need VLV-1010 for AHMED-98. Condition SV.'
data = extractor.extract_aog_data(email, client)
print(data)
